# %%
# importing needed libraries

from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory

from ibm_watsonx_ai.foundation_models import Model
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes, DecodingMethods
from ibm_watson_machine_learning.foundation_models.extensions.langchain import WatsonxLLM
import wget

# %%
# Also you can use this section to suppress warnings generated by code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

#Loading file
filename = 'XVnuuEg94sAE4S_xAsGxBA.txt'
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/XVnuuEg94sAE4S_xAsGxBA.txt'

# Use wget to download the file
wget.download(url, out=filename)
print('file downloaded')
# Out:
# file downloaded

# %%
loader = TextLoader(filename)
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(documents)
print(len(texts))


embeddings = HuggingFaceEmbeddings()
docsearch = Chroma.from_documents(texts, embeddings)  # store the embedding in docsearch using Chromadb
print('document ingested')
# Out:
# 42
# document ingested

# %%
model_id = 'ibm/granite-3-3-8b-instruct' # could be changed to another model like mistralai/mistral-small-3-1-24b-instruct-2503

parameters = {
    GenParams.DECODING_METHOD: DecodingMethods.GREEDY,  
    GenParams.MIN_NEW_TOKENS: 130, # this controls the minimum number of tokens in the generated output
    GenParams.MAX_NEW_TOKENS: 256,  # this controls the maximum number of tokens in the generated output
    GenParams.TEMPERATURE: 0.5 # this randomness or creativity of the model's responses
}

credentials = {
    "url": "https://us-south.ml.cloud.ibm.com"
    # "api_key": "your api key here"
    # uncomment above when running locally
}

project_id = "skills-network"

model = Model(
    model_id=model_id,
    params=parameters,
    credentials=credentials,
    project_id=project_id
)

flan_ul2_llm = WatsonxLLM(model=model)

prompt_template = """
Answer the question ONLY using the information from the context below.

If the answer is not explicitly written in the context,
respond exactly with: "I don't know".

Do NOT use prior knowledge. Do NOT guess.

Context:
{context}

Question: {question}

Answer:
"""


PROMPT = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)

chain_type_kwargs = {"prompt": PROMPT}

qa = RetrievalQA.from_chain_type(llm=flan_ul2_llm, 
                                 chain_type="stuff", 
                                 retriever=docsearch.as_retriever(), 
                                 return_source_documents=True)
query = "Summarize attached document"
qa.invoke(query)
# Out:
# '`apikey` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[5], line 18
#      10 credentials = {
#      11     "url": "https://us-south.ml.cloud.ibm.com"
#      12     # "api_key": "your api key here"
#      13     # uncomment above when running locally
#      14 }
#      16 project_id = "skills-network"
# ---> 18 model = Model(
#      19     model_id=model_id,
#      20     params=parameters,
#      21     credentials=credentials,
#      22     project_id=project_id
#      23 )
#      25 flan_ul2_llm = WatsonxLLM(model=model)
#      27 prompt_template = """
#      28 Answer the question ONLY using the information from the context below.
#      29
#    (...)     40 Answer:
#      41 """
#
# File ~/.local/lib/python3.12/site-packages/ibm_watsonx_ai/foundation_models/model.py:82, in __init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#
# File ~/.local/lib/python3.12/site-packages/ibm_watsonx_ai/foundation_models/inference/model_inference.py:130, in __init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate)
#
# File ~/.local/lib/python3.12/site-packages/ibm_watsonx_ai/client.py:44, in APIClient.__init__(self, wml_credentials, project_id, verify)
#      43 def __init__(self, wml_credentials, project_id=None, verify=None):
# ---> 44     super().__init__(wml_credentials, project_id, verify)
#      46     self._use_fm_ga_api = self._check_if_fm_ga_api_available()  # Remove on CPD 5.0 release
#      47     self.parameter_sets = ParameterSets(self)
#
# File ~/.local/lib/python3.12/site-packages/ibm_watson_machine_learning/client.py:161, in APIClient.__init__(self, wml_credentials, project_id, verify)
#     158             raise WMLClientError(Messages.get_message(message_id="invalid_cloud_scenario_url"))
#     160     if not self._is_IAM():
# --> 161         raise WMLClientError(Messages.get_message(message_id="apikey_not_provided"))
#     162 else:
#     163     if 'icp' == self.wml_credentials[u'instance_id'].lower() or 'openshift' == self.wml_credentials[
#     164         u'instance_id'].lower() or 'wml_local' == self.wml_credentials[u'instance_id'].lower():
#
# WMLClientError: '`apikey` for IAM token is not provided in credentials for the client'
